# %%
# imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_columns", 1000)

# %%
data = pd.read_excel("NSEBANK.xlsx")

# %%
data.head()
# Out:
#         Date     Open     High      Low    Close       ohlc  price_range  \
# 0 2005-06-15  3700.80  3703.75  3662.85  3683.85  3687.8125        40.90
# 1 2005-06-16  3684.40  3685.75  3607.20  3618.80  3649.0375        78.55
# 2 2005-06-17  3625.10  3627.45  3581.80  3595.80  3607.5375        45.65
# 3 2005-06-20  3600.90  3627.35  3518.95  3531.75  3569.7375       108.40
# 4 2005-06-21  3529.05  3587.10  3529.05  3577.50  3555.6750        58.05
#
#    high_wick_range  low_wick_range  open_close_range  high_wick_percent  \
# 0             2.95            21.0            -16.95           0.072127
# 1             1.35            11.6            -65.60           0.017187
# 2             2.35            14.0            -29.30           0.051479
# 3            26.45            12.8            -69.15           0.244004
# 4             9.60             0.0             48.45           0.165375
#
#    low_wick_percent  price_percent      ha_open      ha_high       ha_low  \
# ...
